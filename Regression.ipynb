# %% [markdown]
# # Regression

# %% [markdown]
# 1. What is Simple Linear Regression?
#
#  - Simple Linear Regression is a statistical method that models the relationship between a dependent variable
# Y and a single independent variable
# X using a straight line.

# %% [markdown]
# 2. What are the key assumptions of Simple Linear Regression?
#
#   - Linearity between X and Y
#
#   - Independence of errors
#
#   - Homoscedasticity (constant variance of errors)
#
#   - Normally distributed residuals
#
#   - No multicollinearity (irrelevant in simple regression)

# %% [markdown]
# 3.  What does the coefficient m represent in the equation Y=mX+c ?
#
#  - The coefficient m (slope) represents the change in Y for a one-unit change in X.

# %% [markdown]
# 4. What does the intercept c represent in the equation Y=mX+c?
#
#  - The intercept c is the predicted value of Y when X=0.

# %% [markdown]
# 5. How do we calculate the slope m in Simple Linear Regression?
#
# -  ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. What is the purpose of the least squares method in Simple Linear Regression?
#
#
#  - It minimizes the sum of squared differences between observed and predicted values, producing the best-fitting line.

# %% [markdown]
# 7. How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
#
#   - R² indicates the proportion of variance in the dependent variable that is predictable from the independent variable.

# %% [markdown]
# 8. What is Multiple Linear Regression?
#
#  - It models the relationship between one dependent variable and two or more independent variables.

# %% [markdown]
# 9. What is the main difference between Simple and Multiple Linear Regression?
#
#  - Simple Linear Regression uses one independent variable; Multiple Linear Regression uses two or more.

# %% [markdown]
# 10. What are the key assumptions of Multiple Linear Regression?
#
#
# Linearity
#
# Independence
#
# Homoscedasticity
#
# Normality of residuals
#
# No multicollinearity

# %% [markdown]
# 11. What is heteroscedasticity, and how does it affect the results?
#
#
#  - Heteroscedasticity means non-constant variance of errors. It makes standard errors unreliable, affecting confidence intervals and hypothesis tests.

# %% [markdown]
# 12. How can you improve a Multiple Linear Regression model with high multicollinearity?
#
# Remove or combine correlated variables
#
# Use regularization (e.g., Ridge, Lasso)
#
# Apply Principal Component Analysis (PCA)

# %% [markdown]
# 13. What are some common techniques for transforming categorical variables?
#
#
# One-hot encoding
#
# Label encoding
#
# Binary encoding
#
# Target encoding (with caution)

# %% [markdown]
# 14. What is the role of interaction terms in Multiple Linear Regression?
#
#
#  - They capture combined effects of two or more variables on the dependent variable.

# %% [markdown]
# 15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
#
#  - In Simple Linear Regression, it is the value of Y when X=0. In Multiple Linear Regression, it's the value of Y when all predictors are zero, which might not be meaningful.

# %% [markdown]
# 16. What is the significance of the slope in regression analysis?
#
#  - It quantifies how the dependent variable changes as the independent variable changes.

# %% [markdown]
# 17. How does the intercept in a regression model provide context?
#
#  - It anchors the regression line and shows the baseline level of the dependent variable when predictors are zero.

# %% [markdown]
# 18. What are the limitations of using R² as a sole measure?
#
# It doesn’t account for overfitting
#
# Doesn’t indicate causation
#
# Can be artificially high with many predictors

# %% [markdown]
# 19. How would you interpret a large standard error for a regression coefficient?
#
#
#  - It suggests that the coefficient estimate is unstable and may not be significantly different from zero.

# %% [markdown]
# 20. How can heteroscedasticity be identified in residual plots, and why is it important?
#
#  - Look for a funnel shape in residual vs. fitted plots. Addressing it ensures valid inference from the model.

# %% [markdown]
# 21. What does it mean if a model has high R² but low adjusted R²?
#
#  - It indicates overfitting — the model includes irrelevant variables that don't improve prediction.

# %% [markdown]
# 22. Why is it important to scale variables in Multiple Linear Regression?
#
#  - To ensure all predictors contribute equally, especially when regularization is used.

# %% [markdown]
# 23. What is polynomial regression?
#
#  - A form of regression where the relationship between variables is modeled as an nth-degree polynomial.

# %% [markdown]
# 24. How does polynomial regression differ from linear regression?
#
#  - Polynomial regression models curved relationships, while linear regression models straight-line relationships.

# %% [markdown]
# 25. When is polynomial regression used?
#
#  - When data shows a non-linear trend that can’t be captured by linear regression.

# %% [markdown]
# 26. What is the general equation for polynomial regression?
#
#  - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 27. Can polynomial regression be applied to multiple variables?
#
#  - Yes, using polynomial terms for each variable and their interactions.

# %% [markdown]
# 28. What are the limitations of polynomial regression?
#
# Overfitting with high-degree polynomials
#
# Poor extrapolation
#
# Increased complexity

# %% [markdown]
# 29. What methods can evaluate model fit for polynomial degree selection?
#
# Cross-validation
#
# Adjusted R²
#
# AIC/BIC
#
# Residual analysis

# %% [markdown]
# 30. Why is visualization important in polynomial regression?
#
#  - It helps detect underfitting/overfitting and understand the relationship between variables.

# %%
# 31. How is polynomial regression implemented in Python?

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
model.fit(X_train, y_train)
